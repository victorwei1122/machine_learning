# %% [markdown]
# # Costa Rican Household Poverty Analysis
# This notebook serves as the entry point for exploratory data analysis (EDA) and experimental model evaluation for the high-dimensional poverty dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import os

# Add src to path
sys.path.append('../')
from src.data_cleaning import clean_data
from src.feature_engineering import engineer_features

# %% [markdown]
# ## 1. Data Loading & Initial Cleaning

# %%
DATA_PATH = '../data/'
PROCESSED_PATH = '../data/processed/'

# Clean and engineer features
# Note: Place train.csv and test.csv in data/ before running
if os.path.exists(os.path.join(DATA_PATH, 'train.csv')):
    train_cleaned, test_cleaned = clean_data(DATA_PATH, PROCESSED_PATH)
    train_df, test_df = engineer_features(PROCESSED_PATH, PROCESSED_PATH)
else:
    print("Please place train.csv in the data folder.")

# %% [markdown]
# ## 2. Targeted EDA
# Analyze the distribution of the target variable and key features like `meaneduc` (years of education) and `v2a1` (monthly rent).

# %%
if 'Target' in train_df.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x='Target', data=train_df, palette='viridis')
    plt.title('Distribution of Poverty Levels (Target)')
    plt.show()
